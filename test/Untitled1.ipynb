# %%
from satpy.utils import check_satpy
check_satpy()
# Out:
# Readers
# ...
# abi_l1b:  ok
# abi_l1b_scmi:  ok
# abi_l2_nc:  ok
# acspo:  cannot find module 'satpy.readers.acspo' (DLL load failed while importing _netCDF4: The specified procedure could not be found.)
# agri_fy4a_l1:  ok
# agri_fy4b_l1:  ok
# ahi_hrit:  ok
# ahi_hsd:  ok
# ahi_l1b_gridded_bin:  ok
# ahi_l2_nc:  ok
# ami_l1b:  ok
# amsr2_l1b:  ok
# amsr2_l2:  ok
# amsr2_l2_gaasp:  ok
# amsub_l1c_aapp:  ok
# ascat_l2_soilmoisture_bufr:  cannot find module 'satpy.readers.ascat_l2_soilmoisture_bufr' (('Missing eccodes-python and/or eccodes C-library installation. Use conda to install eccodes.\n           Error: ', ModuleNotFoundError("No module named 'eccodes'")))
# atms_l1b_nc:  cannot find module 'satpy.readers.atms_l1b_nc' (DLL load failed while importing _netCDF4: The specified procedure could not be found.)
# atms_sdr_hdf5:  ok
# avhrr_l1b_aapp:  ok
# avhrr_l1b_eps:  ok
# avhrr_l1b_gaclac:  cannot find module 'satpy.readers.avhrr_l1b_gaclac' (No module named 'pygac')
# ...
